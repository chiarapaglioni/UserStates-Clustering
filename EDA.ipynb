# %% [markdown]
# ## EDA and Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read data
file_path = 'data/raw_data.csv'
df = pd.read_csv(file_path)

# %%
print("Data Info:")
print(df.info())
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5811 entries, 0 to 5810
# Data columns (total 54 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User ID           5811 non-null   object
#  1   Phone             5811 non-null   int64
#  2   Gender            5811 non-null   object
#  3   Age               5811 non-null   int64
#  4   Weight            5811 non-null   int64
#  5   Height            5811 non-null   int64
#  6   Date/Time         5811 non-null   object
#  7   Tiredness         5443 non-null   float64
#  8   Calm              5457 non-null   float64
#  9   Nutrition         5437 non-null   float64
#  10  Hydration         5437 non-null   float64
#  11  Performance       5067 non-null   float64
#  12  Concentrate       1598 non-null   float64
#  13  Happy             1346 non-null   float64
#  14  Determined        733 non-null    float64
#  15  Excited           527 non-null    float64
# ...

# %%
df.head()
# Out:
#                         User ID         Phone Gender  Age  Weight  Height  \
# 0  YzrhxnFG8qO066LqOWE5csQg59x2  447500641470    man   17      96     183
# 1  YzrhxnFG8qO066LqOWE5csQg59x2  447500641470    man   17      96     183
# 2  YzrhxnFG8qO066LqOWE5csQg59x2  447500641470    man   17      96     183
# 3  YzrhxnFG8qO066LqOWE5csQg59x2  447500641470    man   17      96     183
# 4  YzrhxnFG8qO066LqOWE5csQg59x2  447500641470    man   17      96     183
#
#                   Date/Time  Tiredness   Calm  Nutrition  ...       Actions  \
# 0  2023-07-22T10:18:14.805Z       50.0  100.0       91.0  ...  Social media
# 1  2023-07-23T08:24:41.507Z       50.0   50.0      100.0  ...           NaN
# 2  2023-07-23T18:39:49.540Z      100.0  100.0       99.0  ...           NaN
# 3  2023-07-23T23:00:04.538Z       50.0   50.0       50.0  ...           NaN
# 4  2023-07-26T11:02:15.078Z       41.0   96.0       26.0  ...        Travel
#
# ...

# %%
df.columns
# Out:
# Index(['User ID', 'Phone', 'Gender', 'Age', 'Weight', 'Height', 'Date/Time',
#        'Tiredness', 'Calm', 'Nutrition', 'Hydration', 'Performance',
#        'Concentrate', 'Happy', 'Determined', 'Excited', 'Loving', 'Motivated',
#        'Powerful', 'Helpful', 'Lively', 'Peaceful', 'Proud', 'Optimistic',
#        'Valued', 'Content', 'Hopeful', 'Confident', 'Relieved', 'Annoyed',
#        'Nervous', 'Overwhelmed', 'Irritated', 'Anxious', 'Afraid', 'Angry',
#        'Worried', 'Bored', 'Lonely', 'Weary', 'Disappointed', 'Confused',
#        'Embarrassed', 'Sad', 'Actions', 'With', 'Reflections', 'Steps',
#        'Sleep', 'HRV', 'Sleep Heart Rate', 'Glucose', 'Callories Burn',
#        'Calories Intake'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
emotion_targets = ['Happy', 'Determined', 'Excited', 'Loving', 'Motivated', 'Powerful',
                   'Helpful', 'Lively', 'Peaceful', 'Proud', 'Optimistic', 'Valued',
                   'Content', 'Hopeful', 'Confident', 'Relieved', 'Annoyed', 'Nervous',
                   'Overwhelmed', 'Irritated', 'Anxious', 'Afraid', 'Angry', 'Worried',
                   'Bored', 'Lonely', 'Weary', 'Disappointed', 'Confused', 'Embarrassed', 'Sad']

wearable_data = ['Steps', 'Sleep', 'HRV', 'Sleep Heart Rate',
                 'Glucose', 'Callories Burn', 'Calories Intake']

general_data = ['User ID', 'Phone', 'Gender', 'Age', 'Weight', 'Height', 'Tiredness', 'Calm', 'Nutrition',
                'Hydration', 'Performance', 'Concentrate']

text_data = ['Actions', 'With', 'Reflections']

# Define category sizes
emotion_categories = {
    'Emotion Targets': len(emotion_targets),
    'Wearable Data': len(wearable_data),
    'User Data': len(general_data), 
    'Text Data': len(text_data), 
}

# Create pie chart
labels = list(emotion_categories.keys())
sizes = list(emotion_categories.values())

# Set up the figure size
plt.figure(figsize=(8, 6))

# Create the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Add a legend to the side of the pie chart
plt.legend(labels, title="Categories", bbox_to_anchor=(1.05, 0.5), loc='center left')

# Save the plot
plot_path = "plots/pie-chart.png"
plt.savefig(plot_path, bbox_inches='tight')

# Show the plot
plt.show()

# %%
print(f"Shape of the dataset: {df.shape}")

print("Data Types:")
print(df.dtypes)
# Out:
# Shape of the dataset: (5811, 54)
# Data Types:
# User ID              object
# Phone                 int64
# Gender               object
# Age                   int64
# Weight                int64
# Height                int64
# Date/Time            object
# Tiredness           float64
# Calm                float64
# Nutrition           float64
# Hydration           float64
# Performance         float64
# Concentrate         float64
# Happy               float64
# Determined          float64
# Excited             float64
# Loving              float64
# Motivated           float64
# Powerful            float64
# Helpful             float64
# Lively              float64
# Peaceful            float64
# Proud               float64
# Optimistic          float64
# Valued              float64
# Content             float64
# Hopeful             float64
# Confident           float64
# Relieved            float64
# Annoyed             float64
# Nervous             float64
# ...

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# User ID                0
# Phone                  0
# Gender                 0
# Age                    0
# Weight                 0
# Height                 0
# Date/Time              0
# Tiredness            368
# Calm                 354
# Nutrition            374
# Hydration            374
# Performance          744
# Concentrate         4213
# Happy               4465
# Determined          5078
# Excited             5284
# Loving              5590
# Motivated           4826
# Powerful            5620
# Helpful             5654
# Lively              5636
# Peaceful            4968
# Proud               5333
# Optimistic          5335
# Valued              5558
# Content             4988
# Hopeful             5481
# Confident           5589
# Relieved            5605
# Annoyed             5627
# Nervous             5337
# Overwhelmed         5544
# Irritated           5670
# Anxious             5307
# Afraid              5714
# Angry               5744
# ...
